# %% [markdown]
# # Problem Set 1

# %%
import chant
cd = chant.chantData
nd = chant.noteData

import pandas as pd

from IPython.core.display import display, HTML

# %%
pd.crosstab(cd.Modus, cd.subcorpus)
# Out:
# subcorpus  Feast  Humbert  Humbert Sanct.  Humbert Temp.  Saint
# Modus
# 1d           100       63             235            293    468
# 1e             0        0               0              0      1
# 1v             0        8              43             59     12
# 2a             0        0               2              7      0
# 2d            55       11              84            100    253
# 2g             0        0               0              0      4
# 2v             0        2              28             44      8
# 3e            56       11              64             87    247
# 3v             0        3              20             29      5
# 4a             0        9              13             63      1
# 4b             0        0               0              1      0
# 4e            63        9              86            103    236
# 4v             0        2              23             30      4
# 5c             5        1               0              0     15
# ...

# %%
display(chant.fullService)
display(chant.fullGenre)
# Out:
# {'$': 'suffrage',
#  'C': 'Compline',
#  'H': 'LittleHrs',
#  'L': 'Lauds',
#  'M': 'Matins',
#  'N': 'Nones',
#  'P': 'Prime',
#  'Q': 'unknown',
#  'R': 'Procession',
#  'S': 'Sext',
#  'T': 'Terce',
#  'U': 'other',
#  'V': 'Vespers&nbsp;1',
#  'W': 'Vespers&nbsp;2'}
# {'$': 'suffrage (usually an antiphon)',
#  'A': 'psalm antiphon (Agnus at Mass)',
#  'D': 'dialogue (versicle and response)',
#  'E': 'canticle antiphon',
#  'H': 'hymn',
#  'I': 'invitatory',
#  'J': 'alleluia at Mass',
#  'K': 'canticle text (Kyrie at Mass)',
#  'Q': 'sequence',
#  'R': 'responsory (gradual at Mass)',
#  'U': 'alleluia verse',
#  'V': 'verse of responsory (gradual at Mass)',
#  'W': 'verse (not responsory or alleluia)',
#  'X': 'doxology',
#  'Z': 'Benedicamus Domino',
#  'a': 'antiphon or Agnus [incipit]',
#  'i': 'invitatory [incipit]',
#  'l': 'lesson [incipit]',
#  'r': 'responsory or gradual [incipit]',
#  'v': 'verse of responsory or gradual [incipit]',
#  'O': 'other',
#  'T': 'incipit'}

# %%
chant.fullService['W']
# Out:
# 'Vespers&nbsp;2'
